# %%
import numpy as np
import matplotlib.pylab as plt

import pandas as pd
import seaborn as sns

# %%
infile = 'extracted_results.csv'
df = pd.read_csv(infile)

# %%
df

# %%
df['datetime'] = pd.to_datetime(df['Date'])

df

# %%
df.plot.scatter(x='datetime', y='Size_Events', s=60)
plt.yscale('log')

# %%
from textwrap import wrap

# %%
#sns.scatterplot(data=df, x='datetime', y='Size_Events', hue='Dataset_Name', style='Dataset_Name', s=500)
sns.scatterplot(data=df, x='datetime', y='Size_Events', hue='Title', style='Title', s=500)

plt.yscale('log')

leg = plt.legend()


#labels = [ '\n'.join(wrap(l, 20)) for l in df.columns]

#plt.gca().legend(labels, bbox_to_anchor=(1, 0.5))

# %%
df['Size_Events']/1e9

# %%
df['Size_Bytes']/1e12

# %%
df['Dataset_Name'].iloc[0]
